# %%
import json

# %%
county_geojson_file = open('data/cb_2016_us_county_20m_geo.json', 'r')
county_geojson = json.load(county_geojson_file)
county_geojson_file.close()

# %%
county_geojson['features'][0]['properties']['GEOID']
# Out:
# '39131'

# %%
for feature in county_geojson['features']:
    print('"{}": false,'.format(feature['properties']['GEOID']))
# Out:
# "39131": false,
# "46003": false,
# "55035": false,
# "72145": false,
# "48259": false,
# "40015": false,
# "19093": false,
# "28071": false,
# "12027": false,
# "31137": false,
# "26143": false,
# "16075": false,
# "45083": false,
# "36009": false,
# "18037": false,
# "19147": false,
# "20207": false,
# "26025": false,
# "31099": false,
# "40149": false,
# "46057": false,
# "72129": false,
# "48081": false,
# "72019": false,
# "20181": false,
# "29081": false,
# "40135": false,
# "08035": false,
# "18059": false,
# "19013": false,
# "22061": false,
# "29107": false,
# "39047": false,
# "48163": false,
# "48445": false,
# "72061": false,
# "56031": false,
# "19099": false,
# "20035": false,
# "38039": false,
# "22021": false,
# "27017": false,
# "18087": false,
# "20209": false,
# "19195": false,
# "31135": false,
# "08095": false,
# "29003": false,
# "36117": false,
# "36071": false,
# "13195": false,
# "31151": false,
# "17081": false,
# "19067": false,
# "19107": false,
# ...
